# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import seaborn as sns

import pychart

# Input data files are available in the read-only "/input" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/Users/user/AB/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
# create python env using command: python -m venv env
# activate env using command: source env/bin/activate

# %%
penguins = sns.load_dataset('penguins')

sns.displot(penguins, x="flipper_length_mm")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", element="step")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="sex", multiple="dodge")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", kind="kde")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", kind="kde", fill=True)

# %%
sns.displot(penguins, x="body_mass_g", hue="species", kind="ecdf")

# %%
sns.displot(penguins, x="body_mass_g", hue="species", kind="ecdf", stat="count")

# %%
sns.displot(penguins, x="body_mass_g", hue="sex", kind="kde")

# %%
sns.jointplot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %%
sns.pairplot(penguins, hue="species", height=3, diag_kind="hist")

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Mar 17 09:17:28 2021

@author: Amalia
"""

import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv ('grands.csv')

pd.set_option("display.max.columns", None)

#print(df.head())

#df.plot(x="Rank", y=["P25th", "Median", "P75th"])
#plt.show()

# median_column = df["Median"]
# # print(type(median_column))
# median_column.plot(kind="hist")

# top_5 = df.sort_values(by="Median", ascending=False).head()
# top_5.plot(x="Major", y="Median", kind="bar", rot=10, fontsize=7)

# top_10 = df.sort_values(by="Median", ascending=False).head(10)
# top_10.plot(x="Major", y="Median", kind="bar", rot=10, fontsize=6)

# top_medians = df[df["Median"] > 58000].sort_values("Median")
# top_medians.plot(x="Major", y=["P25th", "Median", "P75th"], kind="bar")


cat_totals = df.groupby("Major_category")["Total"].sum().sort_values()

small_cat_totals = cat_totals[cat_totals < 100_000]
big_cat_totals = cat_totals[cat_totals > 100_000]

# Adding a new item "Other" with the sum of the small categories
small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])
big_cat_totals = big_cat_totals.append(small_sums)
big_cat_totals.plot(kind="pie", label="")

# %%
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris, hue="species", height=3, diag_kind="hist")
