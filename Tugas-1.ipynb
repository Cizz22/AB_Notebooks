# %% [markdown]
# Aulia Cisatra
# 5026201124
#
# # Data Set
# Using customers dataset. Download from
# `https://www.kaggle.com/datasets/datascientistanna/customers-dataset`

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read CSV

# %%
data = pd.read_csv('/Users/user/AB/data/Sleep_Efficiency.csv')

# %% [markdown]
# ## Line graph using matplotlib

# %%
data
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    24
# ...

# %%
sns.lmplot(x='Age', y='Sleep efficiency', data=data, hue="Gender")
plt.title('Scatter Plot Sleep Efficiency vs Age')
# Out:
# Text(0.5, 1.0, 'Scatter Plot Sleep Efficiency vs Age')

# %%
# Set theme
sns.set_style('whitegrid')
 
# Violin plot
plt.figure(figsize=(10,8)) # Set plot dimensions
sns.violinplot(x='Smoking status', y='Sleep efficiency', data=data)

plt.title('Violin plot of Sleep Efficiency vs Smoking Status')
# Out:
# Text(0.5, 1.0, 'Violin plot of Sleep Efficiency vs Smoking Status')

# %%
# Categorical Plot
g = sns.catplot(x='Exercise frequency',
                   y='Sleep efficiency', 
                   data=data, 
                   hue='Smoking status',  # Color by stage
                   col='Smoking status',  # Separate by stage
                   kind='swarm') # Swarmplot
 
# Rotate x-axis labels
g.set_xticklabels(rotation=-45)

plt.title('Categorical Plot of Sleep Efficiency vs Exercise Frequency and Smoking Status')
